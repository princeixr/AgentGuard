# %% [markdown]
# # AgentGuard Trace Search
#
# Use this notebook to inspect `agentguard-traces-v1` records in Elastic.

# %%
import json, os, urllib.request

ELASTICSEARCH_URL = os.environ.get('ELASTICSEARCH_URL', '').rstrip('/')
ELASTICSEARCH_API_KEY = os.environ.get('ELASTICSEARCH_API_KEY', '')
INDEX = os.environ.get('AGENTGUARD_ELASTIC_TRACES_INDEX', 'agentguard-traces-v1')

headers = {'Content-Type': 'application/json'}
if ELASTICSEARCH_API_KEY:
    headers['Authorization'] = f'ApiKey {ELASTICSEARCH_API_KEY}'

# %%
query = {
    'size': 10,
    'query': {'term': {'intent.domain': 'email'}},
    'sort': [{'@timestamp': {'order': 'desc'}}],
}
request = urllib.request.Request(
    f'{ELASTICSEARCH_URL}/{INDEX}/_search',
    data=json.dumps(query).encode('utf-8'),
    headers=headers,
    method='POST',
)
with urllib.request.urlopen(request) as response:
    result = json.loads(response.read().decode('utf-8'))
[(hit['_source']['trace_id'], hit['_source']['proposed_tool_call']['tool_name']) for hit in result['hits']['hits']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       1 query = {
#       2     'size': 10,
#       3     'query': {'term': {'intent.domain': 'email'}},
#       4     'sort': [{'@timestamp': {'order': 'desc'}}],
#       5 }
# ----> 6 request = urllib.request.Request(
#       7     f'{ELASTICSEARCH_URL}/{INDEX}/_search',
#       8     data=json.dumps(query).encode('utf-8'),
#       9     headers=headers,
#      10     method='POST',
#      11 )
#      12 with urllib.request.urlopen(request) as response:
#      13     result = json.loads(response.read().decode('utf-8'))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:322, in Request.__init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     319 def __init__(self, url, data=None, headers={},
#     320              origin_req_host=None, unverifiable=False,
#     321              method=None):
# --> 322     self.full_url = url
#     323     self.headers = {}
#     324     self.unredirected_hdrs = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:348, in Request.full_url(self, url)
#     346 self._full_url = unwrap(url)
#     347 self._full_url, self.fragment = _splittag(self._full_url)
# --> 348 self._parse()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:377, in Request._parse(self)
#     375 self.type, rest = _splittype(self._full_url)
#     376 if self.type is None:
# --> 377     raise ValueError("unknown url type: %r" % self.full_url)
#     378 self.host, self.selector = _splithost(rest)
#     379 if self.host:
#
# ValueError: unknown url type: '/agentguard-traces-v1/_search'
